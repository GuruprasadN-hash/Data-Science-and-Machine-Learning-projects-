# %% [markdown]
# # Business Case: Aerofit - Descriptive Statistics & Probability

# %% [markdown]
# **Introduction**: Aerofit is a leading brand in the field of fitness equipment. Aerofit provides a product range including machines such as treadmills, exercise bikes, gym equipment, and fitness accessories to cater to the needs of all categories of people.

# %% [markdown]
# **Business Problem:** The market research team at AeroFit wants to identify the characteristics of the target audience for each type of treadmill offered by the company, to provide a better recommendation of the treadmills to the new customers. The team decides to investigate whether there are differences across the product with respect to customer characteristics.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
! gdown "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749" -O output_filename.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/001/125/original/aerofit_treadmill.csv?1639992749
# To: /content/output_filename.csv
# 100% 7.28k/7.28k [00:00<00:00, 33.8MB/s]

# %%
df = pd.read_csv("output_filename.csv")
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     KP281   18    Male         14        Single      3        4   29562
# 1     KP281   19    Male         15        Single      2        3   31836
# 2     KP281   19  Female         14     Partnered      4        3   30699
# 3     KP281   19    Male         12        Single      3        3   32973
# 4     KP281   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   KP781   40    Male         21        Single      6        5   83416
# 176   KP781   42    Male         18        Single      5        4   89641
# 177   KP781   45    Male         16        Single      5        5   90886
# 178   KP781   47    Male         18     Partnered      4        5  104581
# 179   KP781   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# **Charactersticks of Dataset:**

# %% [markdown]
# Shape of the Dataset

# %%
df.shape
# Out:
# (180, 9)

# %% [markdown]
# **Observation:**
# There are 180 rows and 9 columns in the data set.

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   KP281   18    Male         14        Single      3        4   29562    112
# 1   KP281   19    Male         15        Single      2        3   31836     75
# 2   KP281   19  Female         14     Partnered      4        3   30699     66
# 3   KP281   19    Male         12        Single      3        3   32973     85
# 4   KP281   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# **Datatypes in Dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# **Observation:**
# The DataSet Consist of columns having 6 int Datatype and 2 Object Datatype.

# %% [markdown]
# **Null value detection**

# %%
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# **Observation:** Here we see there are no null values in the DataSet.

# %% [markdown]
# **Describe the Dataset**

# %%
df.describe(include = "all")
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      KP281         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df.value_counts()
# Out:
# Product  Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  Miles
# KP281    18   Male    14         Single         3      4        29562   112      1
# KP481    30   Female  13         Single         4      3        46617   106      1
#          31   Female  16         Partnered      2      3        51165   64       1
#                       18         Single         2      1        65220   21       1
#               Male    16         Partnered      3      3        52302   95       1
#                                                                                 ..
# KP281    34   Female  16         Single         2      2        52302   66       1
#               Male    16         Single         4      5        51165   169      1
#          35   Female  16         Partnered      3      3        60261   94       1
#                       18         Single         3      3        67083   85       1
# ...

# %% [markdown]
# **Observation:**
#
# 1. There are totally 104 males and 76 Females practising Gym in Aerofit machines.
# 2. KP281 is most frequently used treadmill product.
# 3. Minimum and maximum age of the person using treadmill is 18 and 50 respectively.
# 4. Mean and Median age of the person is 28.79 and 26 reslectively. 75 % of the users below 33 years age are involved in treadmill usage.
# 5. Maximum usage of the treadmill between 24 to 26 years of age.
# 6. 75% of the users have less then 16 years of education.
# 7. Miles and income attributes have higher standard deviation. So it reveals that there is significant amount of diversity and variability in the dataset.
# 8. There are no missing values in the Dataset.

# %% [markdown]
# # GRAPHICAL ANALYSIS

# %% [markdown]
# **Univariate Analysis:**

# %% [markdown]
# Following are the attributes on which the univariate analysis have been visualized.
#
# 1. Age
# 2. Education
# 3. Usage
# 4. Fitness
# 5. Income
# 6. Miles

# %% [markdown]
# **Detecting Outliers by using boxplot**

# %%
fig, axis = plt.subplots(nrows = 3, ncols = 2, figsize=[20, 10])
fig.subplots_adjust(top = 1.0)

sns.boxplot(data=df, x="Age", ax=axis[0,0])
sns.boxplot(data=df, x="Education", ax=axis[0,1])
sns.boxplot(data=df, x="Usage", ax=axis[1,0])
sns.boxplot(data=df, x="Fitness", ax=axis[1,1])
sns.boxplot(data=df, x="Income", ax=axis[2,0])
sns.boxplot(data=df, x="Miles", ax=axis[2,1])
plt.show()

# %% [markdown]
# **Observations:**
#
# 1. Income and Miles attributes have more outliers belyond maximum value compared to other attributes of the Dataset.
# 2. The differencce between mean and median for income and miles attributes in the dataset is significant compared to other attribute. It indicates that presence of Outliers.

# %% [markdown]
# **Countplot**

# %%
fig, axis = plt.subplots(nrows=3, ncols=2, figsize=[20, 10])
fig.subplots_adjust(top=1.0)

sns.countplot(data=df, x="Age", ax=axis[0,0])
sns.countplot(data=df, x="Education", ax=axis[0,1])
sns.countplot(data=df, x="Usage", ax=axis[1,0])
sns.countplot(data=df, x="Fitness", ax=axis[1,1])
sns.countplot(data=df, x="Income", ax=axis[2,0])
sns.countplot(data=df, x="Miles", ax=axis[2,1])
plt.show()

# %% [markdown]
# **Observatins:**
#
# 1. Treadmill users are high in 25 years age category.
# 2. 16 years educated users high in Treadmill usage.
# 3. Users use treadmill 3 days a week as maximum.
# 4. Fitness of most users is Medium level.
# 5. Users coverage of miles is more at 85.

# %% [markdown]
# # Histplot

# %%
fig, axis = plt.subplots(nrows = 3, ncols = 2, figsize=[20, 10])
fig.subplots_adjust(top=1.0)

sns.histplot(data=df, x="Age", ax=axis[0,0])
sns.histplot(data=df, x="Education", ax=axis[0,1])
sns.histplot(data=df, x="Usage", ax=axis[1,0])
sns.histplot(data=df, x="Fitness", ax=axis[1,1])
sns.histplot(data=df, x="Income", ax=axis[2,0])
sns.histplot(data=df, x="Miles", ax=axis[2,1])
plt.show()

# %% [markdown]
# **Conclusion:**
#
# Most of the treadmill users falls under the income of 50,000/- to 55,000/-.

# %%
fig, axis = plt.subplots(nrows=1, ncols=2, figsize=[20, 10])
sns.countplot(data=df, x="Age", ax=axis[0])
sns.countplot(data=df, x="MaritalStatus", ax=axis[1])
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# **Distribution of the data for product and Age using Countplot.**

# %%
sns.countplot(data=df, x="Product", hue="Age")
plt.ylabel("Age")
plt.show()

# %% [markdown]
# **Distribution of data for product and Marital Status using Countplot.**

# %%
sns.countplot(data=df, x="Product", hue="MaritalStatus")
plt.show()

# %% [markdown]
# **Observations:**
#
# Treadmills usage is more in Partnered than Single. KP281 is most purchased and used product in both Single and Partnered category.

# %% [markdown]
# **Distribution of Data for Product and Age using Histplot.**

# %%
sns.histplot(data=df, x="Product", y="Age", kde=True)
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %% [markdown]
# **Observations:**
#
# KP281 product usage is more in the 25 years age group compared to other age groups.

# %% [markdown]
# **Distribution of the data for Product and Marital Status using Histplot**

# %%
sns.histplot(data=df, x="Product", y="MaritalStatus", kde=True)
# Out:
# <Axes: xlabel='Product', ylabel='MaritalStatus'>

# %% [markdown]
# **Distribution of the data for Product and Age using boxplot**

# %%
sns.boxplot(data=df, x="Product", y="Age")
# Out:
# <Axes: xlabel='Product', ylabel='Age'>

# %% [markdown]
# **Observations:**
#
# There are lot of outliers in KP781 product usage of all age groups.

# %% [markdown]
# # Marginal Probability

# %%
percentage_of_customers = pd.crosstab(index="Product", columns=df["Product"])/len(df) * 100
percentage_of_customers.round(1)
# Out:
# Product  KP281  KP481  KP781
# row_0
# Product   44.4   33.3   22.2

# %% [markdown]
# # HeatMap

# %% [markdown]
# **Finding Correlation between attributes using HeatMap**

# %%
data = df.corr()
plt.figure(figsize=(7, 5))
sns.heatmap(data, cmap="coolwarm")
plt.show()
# Out:
# <ipython-input-31-4d7ed04249e1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data = df.corr()

# %% [markdown]
# **Observations:**
#
# 1. Fitness and Usage are highly correlated with Miles. It indicated the more the miles run more is fitness and Usage.
#
# 2. Age is negatively correlated with Miles and Usage.

# %% [markdown]
# **Finding Correlation between attributes using Pairplots**

# %%
sns.pairplot(data, diag_kind="hist")
plt.suptitle("Pair plots of Numerical Variables", y = 1.0)
plt.show()

# %%
df1 = pd.crosstab(index=df["Gender"], columns=df["Product"])
df1
# Out:
# Product  KP281  KP481  KP781
# Gender
# Female      40     29      7
# Male        40     31     33

# %%
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
sns.countplot(data=df, x="Product", hue="Gender")
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %% [markdown]
# **Observations:**
#
# 1. There are equal number of Males and Females in KP281 product Purchase.
#
# 2. KP781 product purchase is more in Males than in Females.

# %% [markdown]
# **Finding the probability of Males purchasing KP281, KP481, KP781 treadmill product.**

# %%
def p_prod_given_gender(gender, print_marginal=False):
  if gender != "Female" and gender != "Male":
    return "Invalid gender value."

  df1 = pd.crosstab(index=df['Gender'], columns=[df['Product']])*100
  p_281 = df1['KP281'][gender] / df1.loc[gender].sum()*100
  if print_marginal:
    print(f"P(Male): {df1.loc['Male'].sum()/len(df):.2f}")
    print(f"P(KP281/{gender}): {p_281:.2f}")

p_prod_given_gender('Male', True)
# Out:
# P(Male): 57.78
# P(KP281/Male): 38.46

# %%
def p_prod_given_gender(gender, print_marginal=False):
  if gender != "Female" and gender != "Male":
    return "Invalid gender value."

  df1 = pd.crosstab(index=df['Gender'], columns=[df['Product']])*100
  p_781 = df1['KP781'][gender] / df1.loc[gender].sum()*100
  if print_marginal:
    print(f"P(Male): {df1.loc['Male'].sum()/len(df):.2f}")
    print(f"P(KP781/{gender}): {p_781:.2f}")

p_prod_given_gender('Male', True)
# Out:
# P(Male): 57.78
# P(KP781/Male): 31.73

# %%
def p_prod_given_gender(gender, print_marginal=False):
  if gender != "Female" and gender != "Male":
    return "Invalid gender value."

  df1 = pd.crosstab(index=df['Gender'], columns=[df['Product']])*100
  p_481 = df1['KP481'][gender] / df1.loc[gender].sum()*100
  if print_marginal:
    print(f"P(Male): {df1.loc['Male'].sum()/len(df):.2f}")
    print(f"P(KP481/{gender}): {p_481:.2f}")

p_prod_given_gender('Male', True)
# Out:
# P(Male): 57.78
# P(KP481/Male): 29.81

# %% [markdown]
# **Finding Probability of Females Purchasing KP281, KP481 and KP781 treadmill product.**

# %%
def p_prod_given_gender(gender, print_marginal=False):
  if gender != "Female" and gender != "Male":
    return "Invalid gender value."

  df1 = pd.crosstab(index=df['Gender'], columns=[df['Product']])*100
  p_281 = df1['KP281'][gender] / df1.loc[gender].sum()*100
  if print_marginal:
    print(f"P(Female): {df1.loc['Female'].sum()/len(df):.2f}")
    print(f"P(KP281/{gender}): {p_281:.2f}")

p_prod_given_gender('Female', True)
# Out:
# P(Female): 42.22
# P(KP281/Female): 52.63

# %%
def p_prod_given_gender(gender, print_marginal=False):
  if gender != "Female" and gender != "Male":
    return "Invalid gender value."

  df1 = pd.crosstab(index=df['Gender'], columns=[df['Product']])*100
  p_481 = df1['KP481'][gender] / df1.loc[gender].sum()*100
  if print_marginal:
    print(f"P(Female): {df1.loc['Female'].sum()/len(df):.2f}")
    print(f"P(KP481/{gender}): {p_481:.2f}")

p_prod_given_gender('Female', True)
# Out:
# P(Female): 42.22
# P(KP481/Female): 38.16

# %%
def p_prod_given_gender(gender, print_marginal=False):
  if gender != "Female" and gender != "Male":
    return "Invalid gender value."

  df1 = pd.crosstab(index=df['Gender'], columns=[df['Product']])*100
  p_781 = df1['KP781'][gender] / df1.loc[gender].sum()*100
  if print_marginal:
    print(f"P(Female): {df1.loc['Female'].sum()/len(df):.2f}")
    print(f"P(KP781/{gender}): {p_781:.2f}")

p_prod_given_gender('Female', True)
# Out:
# P(Female): 42.22
# P(KP781/Female): 9.21

# %% [markdown]
# **Observations:**
#
# 1. The probability of purchasing KP281, KP481 and KP781 products by Males are 38.46, 29.81 and 31.72 respectively.
#
# 2. The Probability of purchasing KP281, KP481 and KP781 products by Females are 52.63, 38.16 and 9.21 respectively.

# %%
df["Product"].value_counts(normalize=True).round(1)
# Out:
# KP281    0.4
# KP481    0.3
# KP781    0.2
# Name: Product, dtype: float64

# %% [markdown]
# # Recommendations:

# %% [markdown]
# 1. Create attractive packages specifically for new customers that revolve around treadmill experiences.
# 2. Offer trial periods, introductory discounts, or bundle deals that include personalized treadmill workout plans, guided sessions, and expert
# support.
# 3. Explore whether age, gender, or income influence the choice of treadmill.
# 4. Investigate whether users with weight loss goals prefer certain treadmill features over others.
